# %% [markdown]
# ## 데이터 한눈에 살펴보기
#
# 1. Numerical Variable의 경우
#     - 데이터 통계량()
#     - 평균, 최대, 최소, 사분위수, 중앙값, 갯수
#     - 상관계수
# 2. Categorical Variable의 경우
#     - 고유한 값의 갯수

# %%
import pandas as pd
df = pd.read_csv('credit.csv')
df
# Out:
#       Income  Limit  Rating  Cards  Age  Education  Gender Student Married  \
# 0     14.891   3606     283      2   34         11    Male      No     Yes
# 1    106.025   6645     483      3   82         15  Female     Yes     Yes
# 2    104.593   7075     514      4   71         11    Male      No      No
# 3    148.924   9504     681      3   36         11  Female      No      No
# 4     55.882   4897     357      2   68         16    Male      No     Yes
# ..       ...    ...     ...    ...  ...        ...     ...     ...     ...
# 395   12.096   4100     307      3   32         13    Male      No     Yes
# 396   13.364   3838     296      5   65         17    Male      No      No
# 397   57.872   4171     321      5   67         12  Female      No     Yes
# 398   37.728   2525     192      1   44         13    Male      No     Yes
# 399   18.701   5524     415      5   64          7  Female      No      No
#
#             Ethnicity  Balance
# 0           Caucasian      333
# ...

# %% [markdown]
# ## 전체에 대한 요약값

# %%
df.mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1679             try:
# -> 1680                 x = x.astype(np.complex128)
#    1681             except (TypeError, ValueError):
#
# ValueError: complex() arg is a malformed string
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1682                 try:
# -> 1683                     x = x.astype(np.float64)
#    1684                 except ValueError as err:
#
# ValueError: could not convert string to float: '......
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# ## 개별 칼럼에 대한 요약값

# %%
print(df['Income'].mean()) # 평균
print(df['Income'].max()) # 최대값
print(df['Income'].median()) # 중앙값
print(df['Income'].min()) # 최소값
print(df['Income'].std()) # 표준편차
# Out:
# 45.218885
# 186.634
# 33.1155
# 10.354
# 35.244273165070524

# %% [markdown]
# ## 수치형 데이터에 대하여 한눈에 요약통계량 보기

# %%
df.describe()
# Out:
#            Income         Limit      Rating       Cards         Age  \
# count  400.000000    400.000000  400.000000  400.000000  400.000000
# mean    45.218885   4735.600000  354.940000    2.957500   55.667500
# std     35.244273   2308.198848  154.724143    1.371275   17.249807
# min     10.354000    855.000000   93.000000    1.000000   23.000000
# 25%     21.007250   3088.000000  247.250000    2.000000   41.750000
# 50%     33.115500   4622.500000  344.000000    3.000000   56.000000
# 75%     57.470750   5872.750000  437.250000    4.000000   70.000000
# max    186.634000  13913.000000  982.000000    9.000000   98.000000
#
#         Education      Balance
# count  400.000000   400.000000
# mean    13.450000   520.015000
# std      3.125207   459.758877
# min      5.000000     0.000000
# 25%     11.000000    68.750000
# 50%     14.000000   459.500000
# 75%     16.000000   863.000000
# max     20.000000  1999.000000

# %% [markdown]
# ## 수치형 변수간 상관계수

# %%
df[['Age','Income','Education','Cards']]
# Out:
#      Age   Income  Education  Cards
# 0     34   14.891         11      2
# 1     82  106.025         15      3
# 2     71  104.593         11      4
# 3     36  148.924         11      3
# 4     68   55.882         16      2
# ..   ...      ...        ...    ...
# 395   32   12.096         13      3
# 396   65   13.364         17      5
# 397   67   57.872         12      5
# 398   44   37.728         13      1
# 399   64   18.701          7      5
#
# [400 rows x 4 columns]

# %%
df[['Age','Income','Education','Cards']].corr()
# Out:
#                 Age    Income  Education     Cards
# Age        1.000000  0.175338   0.003619  0.042948
# Income     0.175338  1.000000  -0.027692 -0.018273
# Education  0.003619 -0.027692   1.000000 -0.051084
# Cards      0.042948 -0.018273  -0.051084  1.000000

# %% [markdown]
# ## 범주형 데이터에 대한 요약값

# %%
# 범주 값과 그의 frequency
df['Ethnicity'].value_counts()
# Out:
# Caucasian           199
# Asian               102
# African American     99
# Name: Ethnicity, dtype: int64

# %%
#고유값만 추려내기
df['Ethnicity'].unique()
# Out:
# array(['Caucasian', 'Asian', 'African American'], dtype=object)

# %% [markdown]
# ## 연습문제

# %% [markdown]
# * auto.csv 데이터를 불러와서 다음에 답하시오
#     - 몇개의 제조국이 있는지 살펴보시오
#     - 몇개의 실린더가 있는지 살펴보시오
#     - 몇개의 연식이 있는지 살펴보시오
#     - 차량 무게의 평균값을 살펴보시오
#     - 차량 무게의 최대값과 최소값을 각각 살펴보시오
#     - 수치형 데이터에 대하여 상관분석을 수행하고, 자동차의 연비에 대한 서로 다른 변수들의 영향을 살펴보시오
#         - 양의 상관관계를 보이는 변수를 찾으시오
#         - 음의 상관관계를 보이는 변수를 찾으시오
