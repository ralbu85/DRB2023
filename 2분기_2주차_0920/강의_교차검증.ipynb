# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/ralbu85/DRB2023/master/Dataset/auto.csv')
df
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0            8         307.0       130.0  3504.0          12.0          70
# 1            8         350.0       165.0  3693.0          11.5          70
# 2            8         318.0       150.0  3436.0          11.0          70
# 3            8         304.0       150.0  3433.0          12.0          70
# 4            8         302.0       140.0  3449.0          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 387          4         140.0        86.0  2790.0          15.6          82
# 388          4          97.0        52.0  2130.0          24.6          82
# 389          4         135.0        84.0  2295.0          11.6          82
# 390          4         120.0        79.0  2625.0          18.6          82
# 391          4         119.0        82.0  2720.0          19.4          82
#
#      origin   mpg
# 0         1  18.0
# 1         1  15.0
# ...

# %%
df = pd.get_dummies(df, columns=['origin'])
df
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0            8         307.0       130.0  3504.0          12.0          70
# 1            8         350.0       165.0  3693.0          11.5          70
# 2            8         318.0       150.0  3436.0          11.0          70
# 3            8         304.0       150.0  3433.0          12.0          70
# 4            8         302.0       140.0  3449.0          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 387          4         140.0        86.0  2790.0          15.6          82
# 388          4          97.0        52.0  2130.0          24.6          82
# 389          4         135.0        84.0  2295.0          11.6          82
# 390          4         120.0        79.0  2625.0          18.6          82
# 391          4         119.0        82.0  2720.0          19.4          82
#
#       mpg  origin_1  origin_2  origin_3
# ...

# %%
y = df['mpg']
X = df.drop(columns = ['mpg'])

# %% [markdown]
# ## Train-test split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,shuffle=True)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression() # 모델 생성
model.fit(X_train, y_train) # 훈련 데이터로 학습
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, r2_score
y_pred = model.predict(X_test) # 검증데이터로 예측
mean_squared_error(y_test,y_pred)
# Out:
# 12.206810486726015

# %%
r2_score(y_test, y_pred)
# Out:
# 0.8219814777746289

# %% [markdown]
# ## K-fold cross validation

# %%
from sklearn.model_selection import KFold, cross_validate
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
kfold = KFold(n_splits=5, shuffle=False)
for a,b in kfold.split(X,y):
    print(a)
    print(b)

# %%
# model = LinearRegression() # 모델 생성
# model = RandomForestRegressor()
kfold = KFold(n_splits=5,shuffle=True) # 교차검증 객체 만들기
metrics = ['neg_mean_squared_error','r2'] # 기록할 평가지표
# https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-parameter

# %%
# 교차검증한 각각의 결과를 기록
result = cross_validate(estimator=model, X=X, y=y, cv=kfold, scoring=metrics, return_train_score=True)
result = pd.DataFrame(result) # 데이터프레임으로 변환

# %%
result.mean()
# Out:
# fit_time                        0.206452
# score_time                      0.006533
# test_neg_mean_squared_error    -7.428814
# train_neg_mean_squared_error   -1.057755
# test_r2                         0.874496
# train_r2                        0.982552
# dtype: float64

# %% [markdown]
# ## 타이타닉

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/ralbu85/DRB2023/master/Dataset/titanic_processed.csv')

# %%
y = df['survived']
X = df.drop(columns=['survived'])

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold, cross_validate

model = LogisticRegression()
# model = RandomForestClassifier()
kfold = KFold(n_splits=5, shuffle=True)
metrics = ['accuracy','precision','recall','roc_auc']
result = cross_validate(estimator=model, X=X, y=y,
                        cv=kfold, scoring=metrics,
                        return_train_score=True)

# %%
result = pd.DataFrame(result)

# %%
result
# Out:
#    fit_time  score_time  test_accuracy  train_accuracy  test_precision  \
# 0  0.051920    0.016965       0.755981        0.794964        0.690141
# 1  0.043236    0.014900       0.822967        0.776978        0.760563
# 2  0.122489    0.032703       0.784689        0.792566        0.752688
# 3  0.104688    0.028097       0.802885        0.803593        0.833333
# 4  0.076985    0.012660       0.783654        0.792814        0.779221
#
#    train_precision  test_recall  train_recall  test_roc_auc  train_roc_auc
# 0         0.780255     0.628205      0.706052      0.832648       0.853686
# 1         0.752294     0.729730      0.700855      0.867918       0.845104
# 2         0.764901     0.760870      0.693694      0.848430       0.850932
# 3         0.781879     0.698925      0.701807      0.841702       0.852461
# 4         0.756250     0.681818      0.718101      0.834328       0.855487

# %%
result.mean()
# Out:
# fit_time           0.079864
# score_time         0.021065
# test_accuracy      0.790035
# train_accuracy     0.792183
# test_precision     0.763189
# train_precision    0.767116
# test_recall        0.699909
# train_recall       0.704102
# test_roc_auc       0.845005
# train_roc_auc      0.851534
# dtype: float64
