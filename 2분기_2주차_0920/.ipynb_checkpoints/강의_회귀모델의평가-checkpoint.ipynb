# %% [markdown]
# ## 데이터 불러오기

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ralbu85/DRB2023/master/Dataset/auto.csv')
df
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0            8         307.0       130.0  3504.0          12.0          70
# 1            8         350.0       165.0  3693.0          11.5          70
# 2            8         318.0       150.0  3436.0          11.0          70
# 3            8         304.0       150.0  3433.0          12.0          70
# 4            8         302.0       140.0  3449.0          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 387          4         140.0        86.0  2790.0          15.6          82
# 388          4          97.0        52.0  2130.0          24.6          82
# 389          4         135.0        84.0  2295.0          11.6          82
# 390          4         120.0        79.0  2625.0          18.6          82
# 391          4         119.0        82.0  2720.0          19.4          82
#
#      origin   mpg
# 0         1  18.0
# 1         1  15.0
# ...

# %%
df = pd.get_dummies(df, columns=['origin'])
df
# Out:
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0            8         307.0       130.0  3504.0          12.0          70
# 1            8         350.0       165.0  3693.0          11.5          70
# 2            8         318.0       150.0  3436.0          11.0          70
# 3            8         304.0       150.0  3433.0          12.0          70
# 4            8         302.0       140.0  3449.0          10.5          70
# ..         ...           ...         ...     ...           ...         ...
# 387          4         140.0        86.0  2790.0          15.6          82
# 388          4          97.0        52.0  2130.0          24.6          82
# 389          4         135.0        84.0  2295.0          11.6          82
# 390          4         120.0        79.0  2625.0          18.6          82
# 391          4         119.0        82.0  2720.0          19.4          82
#
#       mpg  origin_1  origin_2  origin_3
# ...

# %%
y = df['mpg'] # 데이터프레임에서 종속변수 해당 열만 고르기
X = df.drop(columns = ['mpg']) # 데이터프레임에서 종속변수 제거

# %% [markdown]
# ## 모델 학습

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X,y) # 모델 학습
# Out:
# LinearRegression()

# %% [markdown]
# ## 회귀모델의 평가

# %% [markdown]
# ## RMSE

# %%
y_pred = model.predict(X) # 학습된 모델이 예측한 값

# %%
y
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 387    27.0
# 388    44.0
# 389    32.0
# 390    28.0
# 391    31.0
# Name: mpg, Length: 392, dtype: float64

# %%
import numpy as np
np.sqrt((((y_pred - y)**2).sum())/y.count())
# Out:
# 3.2683515153304166

# %%
y.count()
# Out:
# 392

# %% [markdown]
# ## R2

# %%
# TSS
TSS = ((y-y.mean())**2).sum()

# %%
# RSS
RSS = ((y-y_pred)**2).sum()

# %%
R2 = (TSS-RSS)/TSS
R2
# Out:
# 0.8241994699119171

# %% [markdown]
# ## 사이킷 런을 이용한 평가

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
r2_score(y, y_pred) #r2 score
# Out:
# 0.8241994699119172

# %%
np.sqrt(mean_squared_error(y, y_pred)) #rmse score
# Out:
# 3.2683515153304166

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

# %%
mean_absolute_error(y, y_pred)
# Out:
# 2.5053892973783336

# %%
mean_absolute_percentage_error(y,y_pred)
# Out:
# 0.11649088492978549

# %% [markdown]
# ## Housing.csv 데이터 선형회귀모형으로 학습 후, rmse, r2score, mae, mape를 계산해보시오

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ralbu85/DRB2023/master/Dataset/housing.csv')
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df = pd.get_dummies(df,columns=['ocean_proximity']) # 범주형 변수 처리
df = df.dropna() # 누락치 제거

# %%
y = df['median_house_value'] # 종속변수
X = df.drop(columns=['median_house_value']) # 독립변수 선정

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression() # 모델 초기화
reg.fit(X,y) # 모델 학습
y_pred = reg.predict(X) # 모델 예측

# %%
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, mean_absolute_percentage_error
import numpy as np

rmse = np.sqrt(mean_squared_error(y,y_pred)) # RMSE
r2 = r2_score(y,y_pred) # r2
mae = mean_absolute_error(y,y_pred) # MAE
mape = mean_absolute_percentage_error(y, y_pred) # MAPE

# %%
print(rmse, r2, mae, mape
      )
# Out:
# 68635.10693083823 0.6464638320299038 49748.1895182179 0.28671905168244927
